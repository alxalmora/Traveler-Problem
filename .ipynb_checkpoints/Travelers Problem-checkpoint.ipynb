# %%
import pandas as pd
import numpy as np
import mlrose
from matplotlib.animation import FuncAnimation
import math
import json
import time
from random import randint
from matplotlib import pyplot as plt
print ('Librerías Cargadas.')
data = pd.read_csv('DataSet/data.csv', header = None, names=["id", "x", "y"])
print('CSV Cargado.')
# Out:
# Librerías Cargadas.
# CSV Cargado.

# %%
unique_locations = set()
for i in range(0,980):
    unique_locations.add((data['x'][i],data['y'][i]))
print("El Conjunto tiene: "+str(len(unique_locations))+" lugares distintos")
# Out:
# El Conjunto tiene: 634 lugares distintos

# %%
matrix = list(unique_locations)

# %%
plt.figure(figsize=(40,40));
plt.plot([p[0] for p in matrix], [p[1] for p in matrix], 'o');
plt.axis('scaled');
plt.axis("off");
plt.show();

# %% [markdown]
# Mapa de Luxemburgo con las 634 Ubicaciones
# ![](Images/lux980.png)

# %%
fitness_coords = mlrose.TravellingSales(coords = matrix)

# %%
problem_fit = mlrose.TSPOpt(length = 634, fitness_fn = fitness_coords,maximize=False)

# %%
schedule = mlrose.ExpDecay()
arr = []
for max_iters in range(1000,20000,2000):
    for max_attempts in range(50,500,50):
        random = randint(0,1e6)
        start_time = time.time()
        best_state, best_fitness =  mlrose.simulated_annealing(problem_fit, schedule = schedule, max_attempts=max_attempts, max_iters=max_iters, random_state=random)
        elapsed_time = time.time() - start_time
        data = {"algorithm":"simulated_annealing","max_attempts": max_attempts, "max_iters":max_iters, "best_fitness":best_fitness, "best_route":best_state, "time": elapsed_time, "randomize": random}
        print("Best Fitness:"+str(best_fitness)+", time: "+str(elapsed_time))
        arr.append(data)
# Out:
# /home/nexudev/.local/lib/python3.6/site-packages/mlrose/algorithms.py:311: RuntimeWarning: overflow encountered in exp
#   prob = np.exp(delta_e/temp)
# Best Fitness:139445.19287257854, time: 7.554456949234009
# Best Fitness:139828.80027547653, time: 7.44458794593811
# Best Fitness:136331.3984124168, time: 7.314178228378296
# Best Fitness:139654.09924951702, time: 7.44690728187561
# Best Fitness:137093.32557962826, time: 7.394891738891602
# Best Fitness:137749.69056970463, time: 7.417880296707153
# Best Fitness:138884.20421469037, time: 7.4654316902160645
# Best Fitness:140164.41201608407, time: 7.368479251861572
# Best Fitness:136052.63831450138, time: 7.594430923461914
# Best Fitness:109078.85401106693, time: 20.555490732192993
# Best Fitness:106499.56539212355, time: 20.266963958740234
# Best Fitness:108577.65256551813, time: 20.296026945114136
# Best Fitness:106259.12465314817, time: 20.253825902938843
# Best Fitness:108418.8929383955, time: 20.39191436767578
# Best Fitness:108223.70253647096, time: 20.78437042236328
# Best Fitness:111901.31393180696, time: 20.551004648208618
# Best Fitness:103704.6857835826, time: 20.42961311340332
# Best Fitness:107849.56282792361, time: 20.215128898620605
# Best Fitness:110844.35389007119, time: 17.92518424987793
# Best Fitness:95450.98274085569, time: 32.58865022659302
# Best Fitness:94236.4005842141, time: 32.64347791671753
# Best Fitness:95986.88903754775, time: 30.220606565475464
# Best Fitness:97139.83495583481, time: 32.79759502410889
# Best Fitness:95520.40220746619, time: 32.834866523742676
# Best Fitness:94188.18067581342, time: 32.56837320327759
# Best Fitness:94605.77216150211, time: 32.71741437911987
# Best Fitness:92721.24475646202, time: 32.39089393615723
# Best Fitness:96279.43274353574, time: 27.690958261489868
# Best Fitness:89513.72068243736, time: 44.33031988143921
# Best Fitness:89365.58978973428, time: 44.276469230651855
# Best Fitness:84504.90367939172, time: 44.91366219520569
# Best Fitness:87575.07017553298, time: 44.51823401451111
# Best Fitness:88630.67388142676, time: 44.47810339927673
# Best Fitness:87489.38363972575, time: 44.65885925292969
# Best Fitness:88502.99814569978, time: 44.50018882751465
# Best Fitness:86477.60413585909, time: 44.30962252616882
# Best Fitness:98347.12280452017, time: 29.16854190826416
# Best Fitness:84123.37981514745, time: 54.027657985687256
# Best Fitness:84425.08254915506, time: 56.195974349975586
# Best Fitness:83323.10344288978, time: 55.79282259941101
# Best Fitness:82502.65482516367, time: 55.7491934299469
# Best Fitness:81901.81497837306, time: 56.24376821517944
# Best Fitness:83618.8829924783, time: 56.32650804519653
# Best Fitness:79693.046342236, time: 56.414979457855225
# Best Fitness:83536.8235012365, time: 56.19921541213989
# Best Fitness:120030.35273077752, time: 13.533130645751953
# Best Fitness:96030.12033796335, time: 34.27540707588196
# Best Fitness:82943.10084985322, time: 60.76105523109436
# Best Fitness:79651.63233765468, time: 68.00523710250854
# Best Fitness:79017.18602780845, time: 68.05787706375122
# Best Fitness:82597.76401035182, time: 68.10586261749268
# Best Fitness:78908.27363742092, time: 68.73914456367493
# Best Fitness:79510.54822919113, time: 68.51197028160095
# Best Fitness:79495.82886990477, time: 67.90269660949707
# Best Fitness:105220.02514232308, time: 20.87938642501831
# Best Fitness:81725.97337012424, time: 53.93358826637268
# Best Fitness:75202.87630799132, time: 69.82823848724365
# Best Fitness:73693.21190904855, time: 79.60692048072815
# Best Fitness:77214.63771723864, time: 79.78917384147644
# Best Fitness:77894.21032000799, time: 79.4358401298523
# Best Fitness:74424.15303476741, time: 79.38720703125
# Best Fitness:74982.41249895205, time: 79.98228597640991
# Best Fitness:74535.24023506622, time: 80.66439414024353
# Best Fitness:133294.83866748348, time: 8.541646242141724
# Best Fitness:92768.10352152456, time: 34.5063910484314
# Best Fitness:85987.3521835046, time: 47.0509467124939
# Best Fitness:71286.48837581572, time: 91.68818092346191
# Best Fitness:74217.08220078201, time: 90.97044634819031
# Best Fitness:73685.98243805404, time: 91.33136630058289
# Best Fitness:72110.27668318702, time: 91.54286861419678
# Best Fitness:73155.03220062707, time: 91.5482726097107
# Best Fitness:72663.82978632064, time: 91.46980786323547
# Best Fitness:98658.00682688093, time: 25.97947096824646
# Best Fitness:84253.18249874598, time: 48.18502473831177
# Best Fitness:66332.41865179219, time: 103.46301794052124
# Best Fitness:71020.0894773745, time: 102.27357935905457
# Best Fitness:73426.84092882271, time: 97.31928777694702
# Best Fitness:71054.47813877674, time: 103.32618737220764
# Best Fitness:70242.6357382142, time: 103.22716498374939
# Best Fitness:72236.70884815608, time: 103.69175958633423
# Best Fitness:69629.4429857947, time: 103.49117612838745
# Best Fitness:100123.76717752214, time: 26.646138191223145
# Best Fitness:95986.43566442897, time: 31.39280366897583
# Best Fitness:83915.2406807469, time: 57.99068307876587
# Best Fitness:76702.44881392804, time: 72.80533266067505
# Best Fitness:67355.21671474815, time: 115.40859198570251
# Best Fitness:76344.90796831608, time: 97.15346813201904
# Best Fitness:69514.39852600265, time: 114.64468002319336
# Best Fitness:65681.24312153555, time: 115.04752898216248
# Best Fitness:67046.12235807476, time: 115.24616289138794

# %%
for i in range(1,10):
    mut_prob = i/10.0;
    for max_at in range(10,100,20):
        random = randint(0,1e6)
        start_time = time.time()
        best_state, best_fitness = mlrose.genetic_alg(problem_fit, random_state = random, mutation_prob = mut_prob, max_attempts = max_at)
        elapsed_time = time.time() - start_time
        data = {"algorithm":"genetic_alg","mutation_rate": mut_prob, "max_attempts":max_at, "best_fitness":best_fitness, "best_route":best_state, "time": elapsed_time, "randomize": random}
        print("Se ha terminado el algoritmo con: p="+str(mut_prob)+", max_attempt="+str(max_at)+" duration (s)="+str(elapsed_time))
        arr.append(data)
# Out:
# Se ha terminado el algoritmo con: p=0.1, max_attempt=10 duration (s)=34.517141580581665
# Se ha terminado el algoritmo con: p=0.1, max_attempt=30 duration (s)=76.05989456176758
# Se ha terminado el algoritmo con: p=0.1, max_attempt=50 duration (s)=105.97127056121826
# Se ha terminado el algoritmo con: p=0.1, max_attempt=70 duration (s)=298.03549098968506
# Se ha terminado el algoritmo con: p=0.1, max_attempt=90 duration (s)=489.20089530944824
# Se ha terminado el algoritmo con: p=0.2, max_attempt=10 duration (s)=41.35205388069153
# Se ha terminado el algoritmo con: p=0.2, max_attempt=30 duration (s)=66.3310034275055
# Se ha terminado el algoritmo con: p=0.2, max_attempt=50 duration (s)=211.37642788887024
# Se ha terminado el algoritmo con: p=0.2, max_attempt=70 duration (s)=257.1219172477722
# Se ha terminado el algoritmo con: p=0.2, max_attempt=90 duration (s)=187.82014083862305
# Se ha terminado el algoritmo con: p=0.3, max_attempt=10 duration (s)=24.280178785324097
# Se ha terminado el algoritmo con: p=0.3, max_attempt=30 duration (s)=101.49169158935547
# Se ha terminado el algoritmo con: p=0.3, max_attempt=50 duration (s)=257.7368748188019
# Se ha terminado el algoritmo con: p=0.3, max_attempt=70 duration (s)=208.37396717071533
# Se ha terminado el algoritmo con: p=0.3, max_attempt=90 duration (s)=237.5448088645935
# Se ha terminado el algoritmo con: p=0.4, max_attempt=10 duration (s)=35.15753674507141
# Se ha terminado el algoritmo con: p=0.4, max_attempt=30 duration (s)=122.70859169960022
# Se ha terminado el algoritmo con: p=0.4, max_attempt=50 duration (s)=131.9190797805786
# Se ha terminado el algoritmo con: p=0.4, max_attempt=70 duration (s)=222.23376846313477
# Se ha terminado el algoritmo con: p=0.4, max_attempt=90 duration (s)=292.47088623046875
# Se ha terminado el algoritmo con: p=0.5, max_attempt=10 duration (s)=27.959903955459595
# Se ha terminado el algoritmo con: p=0.5, max_attempt=30 duration (s)=90.95624041557312
# Se ha terminado el algoritmo con: p=0.5, max_attempt=50 duration (s)=175.6341106891632
# Se ha terminado el algoritmo con: p=0.5, max_attempt=70 duration (s)=168.52417039871216
# Se ha terminado el algoritmo con: p=0.5, max_attempt=90 duration (s)=234.15386652946472
# Se ha terminado el algoritmo con: p=0.6, max_attempt=10 duration (s)=30.091609716415405
# Se ha terminado el algoritmo con: p=0.6, max_attempt=30 duration (s)=167.05482864379883
# Se ha terminado el algoritmo con: p=0.6, max_attempt=50 duration (s)=158.9257402420044
# Se ha terminado el algoritmo con: p=0.6, max_attempt=70 duration (s)=141.2228376865387
# Se ha terminado el algoritmo con: p=0.6, max_attempt=90 duration (s)=342.25597977638245
# Se ha terminado el algoritmo con: p=0.7, max_attempt=10 duration (s)=33.67507338523865
# Se ha terminado el algoritmo con: p=0.7, max_attempt=30 duration (s)=100.13299131393433
# Se ha terminado el algoritmo con: p=0.7, max_attempt=50 duration (s)=160.78648972511292
# Se ha terminado el algoritmo con: p=0.7, max_attempt=70 duration (s)=250.8944170475006
# Se ha terminado el algoritmo con: p=0.7, max_attempt=90 duration (s)=499.6823296546936
# Se ha terminado el algoritmo con: p=0.8, max_attempt=10 duration (s)=26.60321569442749
# Se ha terminado el algoritmo con: p=0.8, max_attempt=30 duration (s)=91.81884169578552
# Se ha terminado el algoritmo con: p=0.8, max_attempt=50 duration (s)=178.89412999153137
# Se ha terminado el algoritmo con: p=0.8, max_attempt=70 duration (s)=288.5287890434265
# Se ha terminado el algoritmo con: p=0.8, max_attempt=90 duration (s)=311.7612714767456
# Se ha terminado el algoritmo con: p=0.9, max_attempt=10 duration (s)=53.66204500198364
# Se ha terminado el algoritmo con: p=0.9, max_attempt=30 duration (s)=102.1294195652008
# Se ha terminado el algoritmo con: p=0.9, max_attempt=50 duration (s)=178.97948598861694
# Se ha terminado el algoritmo con: p=0.9, max_attempt=70 duration (s)=200.96583318710327
# Se ha terminado el algoritmo con: p=0.9, max_attempt=90 duration (s)=261.42509174346924

# %%
min_distance = 10000000000
p_index = 0;
j_index = 0;
def select_nearest_point(start_index, matrix, visited_index):
    min_index = 0;
    min_distance = 10000000000
    for i in range(0,len(matrix)):
        if(i not in visited_index):
            p_distance = get_distance(matrix[start_index][0],matrix[start_index][1],matrix[i][0],matrix[i][1])
            if(min_distance > p_distance):
                min_distance = min(p_distance, min_distance)
                min_index = i
    return min_index, min_distance
start_time = time.time()
for p in range(0,len(matrix)):
    visited_index = list()
    visited_index.append(p);
    v_distance = 0;
    flag = 1;
    start_point = p;
    while(len(visited_index) < 634 and flag):
        min_index, new_distance = select_nearest_point(start_point,matrix, visited_index)
        visited_index.append(min_index)
        v_distance += new_distance
        if(v_distance >= min_distance):
            flag = 0
        start_point = min_index
    if(v_distance < min_distance):
        route = visited_index
        min_distance = v_distance
elapsed_time = time.time() - start_time
print('Best_Fitness: '+str(min_distance)+', Elapsed_Time: '+str(elapsed_time))
# Out:
# Best_Fitness: 13093.245161922787, Elapsed_Time: 766.8402669429779

# %%
tour = []
for i in range(0, len(route)):
    tour.append((matrix[route[i]][0],matrix[route[i]][1]))
x = np.asarray([p[0] for p in tour])
y = np.asarray([p[1] for p in tour])
fig = plt.figure(figsize=(40,40));
dist = 0
graph, = plt.plot([], [], 'bo-', linewidth=1.5, label=dist, markersize=5)
plt.plot(x,y,'o',color="#b3b3b3",zorder=0)
plt.axis('off')
plt.axis('scaled')
x_init = x[0]
y_init = y[0]
def animate(i):
    global dist 
    global x_init
    global y_init
    dist += get_distance(x_init,y_init, x[i], y[i])
    graph.set_label(dist)
    x_init = x[i]
    y_init = y[i]
    graph.set_data(x[:i+1], y[:i+1])
    graph.set_marker('>')
    graph.set_markersize(15)
    graph.set_markevery(every=[0,i])
    graph.set_markerfacecolor('red')
    plt.legend(prop={'size': 36})
    return graph

def get_distance(x1,y1,x2,y2):
    return math.sqrt((x1-x2)**2+(y1-y2)**2)

ani2 = FuncAnimation(fig, animate, frames=634, interval=100)
ani2.save('best_route_own_code_found.mp4',writer='ffmpeg',extra_args=['-loglevel','verbose'])

# %%
print(route)
# Out:
# [351, 399, 166, 376, 36, 127, 304, 507, 525, 538, 79, 496, 2, 63, 56, 236, 541, 272, 5, 425, 381, 26, 438, 122, 587, 327, 527, 543, 307, 312, 70, 37, 278, 154, 218, 345, 328, 501, 547, 222, 46, 384, 75, 80, 553, 217, 366, 585, 557, 129, 414, 480, 603, 78, 298, 377, 32, 512, 242, 55, 499, 353, 494, 453, 532, 391, 176, 196, 160, 589, 570, 531, 106, 66, 208, 299, 302, 13, 277, 484, 470, 607, 287, 569, 167, 162, 519, 586, 186, 92, 58, 159, 119, 38, 540, 181, 210, 444, 72, 288, 223, 14, 560, 373, 103, 367, 65, 187, 49, 100, 441, 352, 168, 342, 284, 318, 271, 99, 292, 451, 379, 566, 609, 395, 321, 362, 633, 606, 234, 562, 206, 322, 184, 132, 24, 112, 142, 130, 189, 61, 478, 431, 354, 448, 407, 355, 9, 71, 415, 317, 516, 76, 398, 429, 513, 31, 314, 348, 410, 571, 593, 452, 11, 485, 121, 472, 139, 502, 16, 220, 363, 62, 10, 77, 123, 226, 87, 12, 375, 402, 111, 320, 227, 238, 261, 267, 219, 357, 256, 522, 500, 597, 535, 268, 595, 518, 621, 497, 207, 203, 559, 155, 232, 27, 247, 508, 233, 358, 529, 153, 458, 259, 418, 551, 264, 241, 537, 275, 421, 311, 316, 88, 350, 209, 487, 464, 457, 368, 382, 40, 113, 430, 3, 64, 432, 83, 428, 297, 200, 426, 7, 332, 231, 417, 28, 95, 491, 542, 289, 177, 482, 172, 308, 360, 91, 205, 25, 138, 118, 442, 4, 86, 463, 473, 337, 141, 605, 509, 608, 437, 201, 383, 615, 173, 182, 149, 276, 555, 340, 175, 273, 150, 611, 626, 580, 42, 147, 339, 578, 361, 199, 125, 406, 250, 625, 193, 604, 216, 544, 413, 137, 274, 213, 128, 423, 41, 313, 548, 528, 422, 1, 632, 393, 301, 158, 202, 303, 260, 45, 144, 459, 536, 296, 561, 174, 630, 243, 486, 471, 456, 498, 126, 249, 622, 380, 336, 331, 146, 263, 477, 575, 281, 572, 228, 192, 616, 145, 454, 568, 365, 554, 481, 404, 447, 131, 19, 489, 43, 109, 15, 96, 124, 21, 469, 412, 558, 230, 466, 347, 446, 17, 476, 579, 54, 221, 39, 23, 101, 524, 117, 602, 405, 266, 309, 300, 460, 588, 246, 191, 545, 573, 51, 344, 619, 136, 204, 440, 33, 386, 290, 165, 436, 18, 244, 151, 549, 490, 169, 254, 48, 325, 600, 135, 59, 628, 85, 282, 53, 483, 617, 599, 614, 330, 556, 171, 443, 411, 467, 349, 582, 338, 590, 539, 505, 29, 262, 102, 408, 178, 215, 371, 564, 224, 285, 108, 495, 534, 503, 388, 133, 449, 8, 576, 255, 68, 291, 251, 252, 60, 30, 211, 305, 433, 140, 577, 510, 104, 245, 35, 374, 450, 190, 198, 416, 89, 468, 214, 269, 67, 98, 409, 286, 552, 295, 225, 479, 455, 163, 420, 506, 514, 323, 179, 550, 90, 591, 419, 624, 400, 335, 270, 445, 81, 359, 343, 401, 517, 574, 148, 474, 52, 364, 592, 434, 623, 170, 583, 613, 326, 492, 523, 465, 629, 212, 197, 334, 257, 237, 239, 94, 180, 293, 84, 294, 439, 143, 596, 387, 195, 97, 0, 504, 341, 310, 229, 563, 183, 47, 565, 280, 488, 627, 329, 620, 610, 74, 240, 161, 424, 372, 188, 73, 134, 390, 248, 93, 396, 584, 110, 306, 283, 258, 346, 394, 435, 116, 511, 22, 156, 567, 546, 601, 397, 530, 50, 581, 493, 462, 475, 333, 427, 157, 403, 526, 533, 324, 594, 6, 370, 521, 44, 392, 57, 164, 515, 378, 279, 194, 598, 265, 82, 315, 107, 34, 389, 612, 114, 520, 385, 120, 631, 253, 319, 461, 20, 185, 356, 369, 115, 235, 69, 152, 105, 618]
